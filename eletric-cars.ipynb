# %%
import os
import pandas as pd

# Aponta para o arquivo kaggle.json na pasta atual
os.environ['KAGGLE_CONFIG_DIR'] = "."

# Instala a biblioteca do Kaggle (caso não esteja instalada)
# !pip install kaggle -q

# Baixa e extrai os dados direto do Kaggle
# !kaggle datasets download -d sarveshchhetri/ev-battery-failure-prediction-dataset-200k --unzip

# Lê os datasets com o Pandas
df_cars = pd.read_csv("ev_battery_failure_dataset.csv")
df_dict = pd.read_csv("data_dictionary.csv")

# Mostra o resultado
print("Dados carregados com sucesso!")
display(df_cars.head())
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Dataset URL: https://www.kaggle.com/datasets/sarveshchhetri/ev-battery-failure-prediction-dataset-200k
# License(s): CC-BY-SA-4.0
# ...
#   0%|          | 0.00/28.5M [00:00<?, ?B/s]
#   4%|▎         | 1.00M/28.5M [00:00<00:24, 1.16MB/s]
#   7%|▋         | 2.00M/28.5M [00:01<00:16, 1.70MB/s]
#  11%|█         | 3.00M/28.5M [00:01<00:13, 1.98MB/s]
#  14%|█▍        | 4.00M/28.5M [00:02<00:12, 2.14MB/s]
#  18%|█▊        | 5.00M/28.5M [00:02<00:11, 2.23MB/s]
#  21%|██        | 6.00M/28.5M [00:03<00:10, 2.35MB/s]
#  25%|██▍       | 7.00M/28.5M [00:03<00:09, 2.41MB/s]
#  28%|██▊       | 8.00M/28.5M [00:03<00:08, 2.63MB/s]
#  32%|███▏      | 9.00M/28.5M [00:04<00:06, 2.94MB/s]
#  35%|███▌      | 10.0M/28.5M [00:04<00:06, 3.18MB/s]
#  39%|███▊      | 11.0M/28.5M [00:04<00:06, 2.82MB/s]
#  42%|████▏     | 12.0M/28.5M [00:04<00:05, 3.44MB/s]
# ...
